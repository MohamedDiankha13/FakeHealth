# %% [markdown]
# # Notebook 2 — FakeHealth · Baseline Classifier
# ## Pipeline TF-IDF → Classifieurs ML · Table 1 du rapport
#
# **Projet :** A Multi-Source Benchmark for CVD Health Misinformation Detection
# **Dataset :** FakeHealth HealthStory — Dai, Sun & Wang (ICWSM 2020)
# **Prérequis :** Generate the healthStory.csv
#
# ---
# ### What does this notebook do ?
# 1. Load `HealthStory_clean.csv`
# 2. Prepare TF-IDF
# 3. Train two classifers baseline :
#    - Logistic regression
#    - Naive Bayes
# 4. Evaluaion with crossed validation 5-fold
# 5. Calculate the accuracy, precision, recall, F1 (macro + par classe)
# 6. Analyse  errors (confused martrix, examples of errors)
# 7. Analyse the importance of features
# 8. produce **Table 1**
# 9. Save all trained for comparaison with LLMs

# %% [markdown]
# ---
# ## Section 1 — Installation & imports

# %%
# Décommentez si besoin :
# !pip install pandas numpy matplotlib seaborn scikit-learn joblib

import os
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import joblib
from collections import Counter

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import (
    train_test_split, StratifiedKFold,
    cross_val_score, cross_validate
)
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, classification_report, confusion_matrix,
    ConfusionMatrixDisplay
)

sns.set_theme(style='whitegrid', palette='muted', font_scale=1.1)
plt.rcParams['figure.dpi'] = 110

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

print(' Imports OK')
# Out:
#  Imports OK

# %% [markdown]
# ---
# ## Section 2 — Chargement des données
# On charge le CSV exporté par le Notebook 1.
# Si vous n'avez pas encore exécuté le Notebook 1, réglez `CSV_PATH` sur votre propre CSV FakeHealth.

# %%
# ── Chemins possibles du CSV généré par NB1 ─────────────────────────
candidate_paths = [
    '../dataset/healthstory_baseline_ready.csv',
    'HealthStory_clean.csv',
]
# ─────────────────────────────────────────────────────────────────────

CSV_PATH = next((p for p in candidate_paths if os.path.exists(p)), None)
if CSV_PATH is None:
    raise FileNotFoundError(
        'Aucun fichier CSV trouvé parmi:\n'
        + '\n'.join(candidate_paths)
    )

df = pd.read_csv(CSV_PATH, encoding='utf-8')
print(f'All data loaded: {len(df)} articles')
print(f'CSV used: {CSV_PATH}')
# Out:
# All data loaded: 1638 articles
# CSV used: ../dataset/healthstory_baseline_ready.csv

# %%
# VCheck and execute
print('── Raised values ──')
print(df.isnull().sum().to_string())
print()

# SRemove all lines without body and title
n_before = len(df)
df = df.dropna(subset=['label'])

# Colone texte : combine title + body
has_body  = 'body'  in df.columns
has_title = 'title' in df.columns

if has_body and has_title:
    df['text'] = df['title'].fillna('') + ' ' + df['body'].fillna('')
    print(' Colone text = title + body')
elif has_body:
    df['text'] = df['body'].fillna('')
    print(' Colonne text = body uniquement')
elif has_title:
    df['text'] = df['title'].fillna('')
    print('Colonne text = title uniquement (body absent)')
else:
    raise ValueError('Ni "body" ni "title" trouvé dans le CSV.')

df = df[df['text'].str.strip().astype(bool)]  

print(f'   Articles conserved : {len(df)} (removed : {n_before - len(df)})')

X = df['text'].values
y = df['label'].values

print(f'   Fake (0) : {(y==0).sum()} | Real (1) : {(y==1).sum()}')
# Out:
# ── Raised values ──
# file_id         0
# title           0
# text            0
# label           0
# label_name      0
# rating_float    0
# dataset         0
#
# Colonne text = title uniquement (body absent)
#    Articles conserved : 1604 (removed : 0)
#    Fake (0) : 450 | Real (1) : 1154

# %% [markdown]
# ---
# ## Section 3 — Découpage Train / Test
# On utilise un split stratifié 80/20 pour préserver la distribution des classes.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=RANDOM_STATE,
    stratify=y       # ← important : maintient la proportion fake/real
)

print('── Split Train / Test ──')
print(f'  Train : {len(X_train)} articles')
print(f'    Fake : {(y_train==0).sum()} | Real : {(y_train==1).sum()}')
print(f'  Test  : {len(X_test)} articles')
print(f'    Fake : {(y_test==0).sum()} | Real : {(y_test==1).sum()}')
print()
print(' Split stratifié → proportions préservées')
# Out:
# ── Split Train / Test ──
#   Train : 1283 articles
#     Fake : 360 | Real : 923
#   Test  : 321 articles
#     Fake : 90 | Real : 231
#
#  Split stratifié → proportions préservées

# %% [markdown]
# ---
# ## Section 4 — Construction des pipelines TF-IDF
#
# ### Paramètres TF-IDF retenus
# | Paramètre | Valeur | Justification |
# |---|---|---|
# | `ngram_range` | (1, 2) | Capture les expressions bi-mot ('heart disease', 'clinical trial') |
# | `max_features` | 10 000 | Limite le bruit tout en couvrant le vocabulaire médical |
# | `sublinear_tf` | True | Compresse les fréquences élevées (log(1+tf)) — standard NLP |
# | `stop_words` | english | Retire les mots vides non informatifs |
# | `min_df` | 2 | Ignore les termes n'apparaissant qu'une seule fois |
# | `max_df` | 0.95 | Ignore les termes présents dans >95% des docs |

# %%
# Vectoriseur commun aux deux modèles
TFIDF_PARAMS = dict(
    ngram_range  = (1, 2),
    max_features = 10_000,
    sublinear_tf = True,
    stop_words   = 'english',
    min_df       = 2,
    max_df       = 0.95
)

# ── Pipeline 1 : Régression Logistique ───────────────────────────────────
pipe_lr = Pipeline([
    ('tfidf', TfidfVectorizer(**TFIDF_PARAMS)),
    ('clf',  LogisticRegression(
        C           = 1.0,       # régularisation L2 standard
        max_iter    = 1000,
        random_state= RANDOM_STATE,
        class_weight= 'balanced' # compense le léger déséquilibre
    ))
])

# ── Pipeline 2 : Naive Bayes Multinomial ─────────────────────────────────
pipe_nb = Pipeline([
    ('tfidf', TfidfVectorizer(**TFIDF_PARAMS)),
    ('clf',  MultinomialNB(alpha=0.5))  # α=0.5 : lissage de Lidstone
])

# ── Pipeline 3 : LinearSVC (bonus — souvent meilleur sur texte court) ────
pipe_svm = Pipeline([
    ('tfidf', TfidfVectorizer(**TFIDF_PARAMS)),
    ('clf',  LinearSVC(
        C           = 1.0,
        max_iter    = 2000,
        random_state= RANDOM_STATE,
        class_weight= 'balanced'
    ))
])

models = {
    'Logistic Regression': pipe_lr,
    'Naive Bayes':         pipe_nb,
    'LinearSVC':           pipe_svm,
}

print(' 3 pipelines définis')
for name, pipe in models.items():
    print(f'   • {name}')
# Out:
#  3 pipelines définis
#    • Logistic Regression
#    • Naive Bayes
#    • LinearSVC

# %% [markdown]
# ---
# ## Section 5 — Validation croisée 5-fold (stratifiée)
# La validation croisée donne une estimation plus robuste que le simple test set.

# %%
from sklearn.model_selection import cross_validate

SKF = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

cv_results = {}

SCORING = {
    'accuracy' : 'accuracy',
    'f1_macro' : 'f1_macro',
    'precision_macro': 'precision_macro',
    'recall_macro'   : 'recall_macro',
    'f1_fake'  : 'f1_score',   # sera calculé manuellement ci-dessous
}

print('Validation croisée 5-fold en cours...\n')

for name, pipe in models.items():
    cv = cross_validate(
        pipe, X, y,
        cv      = SKF,
        scoring = {
            'accuracy'        : 'accuracy',
            'f1_macro'        : 'f1_macro',
            'precision_macro' : 'precision_macro',
            'recall_macro'    : 'recall_macro',
        },
        return_train_score = False,
        n_jobs = -1
    )
    cv_results[name] = cv

    print(f'── {name} ──')
    print(f'  Accuracy  : {cv["test_accuracy"].mean():.4f} ± {cv["test_accuracy"].std():.4f}')
    print(f'  F1 macro  : {cv["test_f1_macro"].mean():.4f} ± {cv["test_f1_macro"].std():.4f}')
    print(f'  Precision : {cv["test_precision_macro"].mean():.4f} ± {cv["test_precision_macro"].std():.4f}')
    print(f'  Recall    : {cv["test_recall_macro"].mean():.4f} ± {cv["test_recall_macro"].std():.4f}')
    print()
# Out:
# Validation croisée 5-fold en cours...
# ── Logistic Regression ──
#   Accuracy  : 0.5779 ± 0.0138
#   F1 macro  : 0.5107 ± 0.0236
#   Precision : 0.5131 ± 0.0241
#   Recall    : 0.5155 ± 0.0282
#
# ── Naive Bayes ──
#   Accuracy  : 0.7014 ± 0.0137
#   F1 macro  : 0.4704 ± 0.0270
#   Precision : 0.5330 ± 0.0704
#   Recall    : 0.5098 ± 0.0177
#
# ── LinearSVC ──
#   Accuracy  : 0.5804 ± 0.0197
#   F1 macro  : 0.5094 ± 0.0264
#   Precision : 0.5109 ± 0.0258
#   Recall    : 0.5125 ± 0.0281

# %% [markdown]
# ---
# ## Section 6 — Entraînement final et évaluation sur le test set
# On entraîne sur le train set complet et on évalue sur le test set réservé.

# %%
test_results = {}

for name, pipe in models.items():
    # Entraînement sur le train set complet
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)

    test_results[name] = {
        'y_pred'   : y_pred,
        'accuracy' : accuracy_score(y_test, y_pred),
        'prec_macro': precision_score(y_test, y_pred, average='macro'),
        'rec_macro' : recall_score(y_test, y_pred, average='macro'),
        'f1_macro'  : f1_score(y_test, y_pred, average='macro'),
        'f1_fake'   : f1_score(y_test, y_pred, pos_label=0),
        'f1_real'   : f1_score(y_test, y_pred, pos_label=1),
    }

    print(f'── {name} — Test Set ──')
    print(classification_report(y_test, y_pred, target_names=['Fake','Real']))
# Out:
# ── Logistic Regression — Test Set ──
#               precision    recall  f1-score   support
#
#         Fake       0.34      0.42      0.38        90
#         Real       0.75      0.68      0.71       231
#
#     accuracy                           0.61       321
#    macro avg       0.55      0.55      0.54       321
# weighted avg       0.64      0.61      0.62       321
#
# ── Naive Bayes — Test Set ──
#               precision    recall  f1-score   support
#
#         Fake       0.45      0.11      0.18        90
#         Real       0.73      0.95      0.83       231
#
#     accuracy                           0.71       321
#    macro avg       0.59      0.53      0.50       321
# weighted avg       0.65      0.71      0.64       321
#
# ── LinearSVC — Test Set ──
#               precision    recall  f1-score   support
#
#         Fake       0.36      0.44      0.40        90
#         Real       0.76      0.70      0.73       231
#
# ...

# %% [markdown]
# ---
# ## Section 7 — Matrices de confusion

# %%
n_models = len(models)
fig, axes = plt.subplots(1, n_models, figsize=(5 * n_models, 4.5))
if n_models == 1:
    axes = [axes]

for ax, (name, res) in zip(axes, test_results.items()):
    cm = confusion_matrix(y_test, res['y_pred'])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=['Fake', 'Real'])
    disp.plot(ax=ax, colorbar=False, cmap='Blues')
    ax.set_title(f'{name}\nF1-macro = {res["f1_macro"]:.3f}',
                 fontsize=11, fontweight='bold')

    # Annotations : FP/FN
    fn = cm[1][0]  # réels fake prédits real
    fp = cm[0][1]  # réels real prédits fake
    ax.set_xlabel(f'Prédit\n(FP={fp}, FN={fn})')

plt.suptitle('Matrices de confusion — Test Set (20%)',
             fontsize=13, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('fig6_confusion_matrices.png', bbox_inches='tight', dpi=130)
plt.show()
print(' Sauvegardé : fig6_confusion_matrices.png')
# Out:
#  Sauvegardé : fig6_confusion_matrices.png

# %% [markdown]
# ---
# ## Section 8 — Features les plus discriminantes
# Pour la Régression Logistique, les coefficients indiquent quels mots orientent vers Fake ou Real.

# %%
# Extraction des features importantes (Logistic Regression)
lr_pipe = models['Logistic Regression']
vectorizer = lr_pipe.named_steps['tfidf']
classifier = lr_pipe.named_steps['clf']

feature_names = vectorizer.get_feature_names_out()
coefs         = classifier.coef_[0]           # positif → Real, négatif → Fake

TOP_N = 20
idx_top_real = np.argsort(coefs)[-TOP_N:][::-1]
idx_top_fake = np.argsort(coefs)[:TOP_N]

feat_real = [(feature_names[i], coefs[i]) for i in idx_top_real]
feat_fake = [(feature_names[i], coefs[i]) for i in idx_top_fake]

fig, axes = plt.subplots(1, 2, figsize=(15, 7))

# Features → Real
ax = axes[0]
names_r, vals_r = zip(*feat_real)
ax.barh(range(TOP_N), vals_r, color='#2ecc71', alpha=0.8)
ax.set_yticks(range(TOP_N))
ax.set_yticklabels(names_r, fontsize=9)
ax.set_title(f'Top {TOP_N} features → REAL', fontsize=12, fontweight='bold')
ax.set_xlabel('Coefficient (positif = Real)')
ax.invert_yaxis()

# Features → Fake
ax = axes[1]
names_f, vals_f = zip(*feat_fake)
ax.barh(range(TOP_N), [abs(v) for v in vals_f], color='#e74c3c', alpha=0.8)
ax.set_yticks(range(TOP_N))
ax.set_yticklabels(names_f, fontsize=9)
ax.set_title(f'Top {TOP_N} features → FAKE', fontsize=12, fontweight='bold')
ax.set_xlabel('|Coefficient| (négatif = Fake)')
ax.invert_yaxis()

plt.suptitle('Logistic Regression — Features les plus discriminantes',
             fontsize=13, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig('fig7_feature_importance.png', bbox_inches='tight', dpi=130)
plt.show()
print(' Sauvegardé : fig7_feature_importance.png')
# Out:
#  Sauvegardé : fig7_feature_importance.png

# %% [markdown]
# ---
# ## Section 9 — Analyse des erreurs
# Quels articles sont mal classifiés ? Y a-t-il des patterns dans les erreurs ?

# %%
# On utilise LR comme modèle principal pour l'analyse d'erreurs
y_pred_lr = test_results['Logistic Regression']['y_pred']

# Reconstruction robuste des index du test set (même paramètres que le split principal)
all_indices = np.arange(len(df))
_, test_indices = train_test_split(
    all_indices,
    test_size=0.20,
    random_state=RANDOM_STATE,
    stratify=df['label']
)

test_df = df.iloc[test_indices].copy().reset_index(drop=True)
test_df['y_true'] = np.asarray(y_test)
test_df['y_pred'] = np.asarray(y_pred_lr)
test_df['correct'] = (test_df['y_true'] == test_df['y_pred'])

errors = test_df[~test_df['correct']]

print(f'Erreurs totales : {len(errors)} / {len(test_df)} ({100*len(errors)/len(test_df):.1f}%)')
print()

# Faux positifs : articles REAL classifies FAKE
fp = errors[(errors['y_true'] == 1) & (errors['y_pred'] == 0)]
# Faux negatifs : articles FAKE classes REAL
fn = errors[(errors['y_true'] == 0) & (errors['y_pred'] == 1)]

print(f'Faux positifs (Real -> Fake) : {len(fp)}')
print(f'Faux negatifs (Fake -> Real) : {len(fn)}')
print()
print('Attention: les faux negatifs sont critiques (misinformation non detectee).')
# Out:
# Erreurs totales : 126 / 321 (39.3%)
#
# Faux positifs (Real -> Fake) : 74
# Faux negatifs (Fake -> Real) : 52
#
# Attention: les faux negatifs sont critiques (misinformation non detectee).

# %%
# Exemples de faux négatifs (misinformations non détectées)
print('── Exemples de FAUX NÉGATIFS (Fake → prédit Real) ──')
print('   Ces articles contiennent de la désinformation mais ressemblent à du vrai')
print()

text_col = 'text' if 'text' in fn.columns else fn.columns[0]
for i, (_, row) in enumerate(fn.head(3).iterrows()):
    txt = str(row.get('text', row.get('title', 'N/A')))[:300]
    rating = row.get('rating_float', 'N/A')
    print(f'  [{i+1}] rating={rating}')
    print(f'       {txt}...')
    print()

print('── Exemples de FAUX POSITIFS (Real → prédit Fake) ──')
print('   Ces articles sont vrais mais ont des patterns linguistiques ambigus')
print()
for i, (_, row) in enumerate(fp.head(3).iterrows()):
    txt = str(row.get('text', row.get('title', 'N/A')))[:300]
    rating = row.get('rating_float', 'N/A')
    print(f'  [{i+1}] rating={rating}')
    print(f'       {txt}...')
    print()
# Out:
# ── Exemples de FAUX NÉGATIFS (Fake → prédit Real) ──
#    Ces articles contiennent de la désinformation mais ressemblent à du vrai
#
#   [1] rating=2
#        Less Invasive Biopsies Gain Favor...
#
#   [2] rating=2
#        Urine test for prostate cancer may be better than blood test...
#
#   [3] rating=2
#        Study Suggests Osteoporosis Drug Might Treat Loss of Bone in Jaw...
#
# ── Exemples de FAUX POSITIFS (Real → prédit Fake) ──
#    Ces articles sont vrais mais ont des patterns linguistiques ambigus
#
#   [1] rating=3
#        Blood injections may help chronic "tennis elbow"...
#
#   [2] rating=3
#        Outlook, Office, Skype, Bing, Breaking News, and Latest Videos...
#
#   [3] rating=4
#        Ovarian Tissue Transplant Can Help Some Women Have Kids After Cancer Treatment...

# %%
# Distribution des ratings des articles mal classifiés
# Les articles près du seuil (rating ≈ 3) sont les plus difficiles

if 'rating_float' in test_df.columns:
    fig, ax = plt.subplots(figsize=(9, 4))

    bins = np.linspace(0, 5, 25)
    correct = test_df[test_df['correct']]['rating_float'].dropna()
    wrong   = test_df[~test_df['correct']]['rating_float'].dropna()

    ax.hist(correct, bins=bins, alpha=0.65, color='#2ecc71', label='Correct')
    ax.hist(wrong,   bins=bins, alpha=0.8,  color='#e74c3c', label='Erreur')
    ax.axvline(3.0, color='black', linestyle='--', linewidth=1.5, label='Seuil fake/real (3.0)')
    ax.set_xlabel('Rating original (0–5)')
    ax.set_ylabel('Articles')
    ax.set_title('Distribution des ratings : articles corrects vs erreurs\n'
                 '→ La plupart des erreurs sont proches du seuil 3.0',
                 fontsize=11, fontweight='bold')
    ax.legend()
    plt.tight_layout()
    plt.savefig('fig8_error_ratings.png', bbox_inches='tight', dpi=130)
    plt.show()
    print('💾 Sauvegardé : fig8_error_ratings.png')
# Out:
# 💾 Sauvegardé : fig8_error_ratings.png

# %% [markdown]
# ---
# ## Section 10 — Comparaison des modèles (visualisation)
# Graphique comparatif des métriques pour les 3 modèles.

# %%
# Données de comparaison
metrics = ['accuracy', 'f1_macro', 'f1_fake', 'f1_real']
metric_labels = ['Accuracy', 'F1 (macro)', 'F1 (Fake)', 'F1 (Real)']
model_names = list(test_results.keys())

x = np.arange(len(metrics))
width = 0.25
colors = ['#3498db', '#e67e22', '#9b59b6']

fig, ax = plt.subplots(figsize=(11, 5))

for i, (name, res) in enumerate(test_results.items()):
    vals = [res[m] for m in metrics]
    bars = ax.bar(x + i*width, vals, width, label=name,
                  color=colors[i], alpha=0.85, edgecolor='white')
    for bar, v in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width()/2,
                bar.get_height() + 0.005,
                f'{v:.3f}', ha='center', va='bottom', fontsize=8)

ax.set_xticks(x + width)
ax.set_xticklabels(metric_labels, fontsize=11)
ax.set_ylim(0, 1.08)
ax.set_ylabel('Score')
ax.set_title('Comparaison des classifieurs baseline — HealthStory (Test Set 20%)',
             fontsize=12, fontweight='bold')
ax.legend(fontsize=10)
ax.axhline(0.5, color='gray', linestyle=':', alpha=0.5, label='Chance level')

plt.tight_layout()
plt.savefig('fig9_model_comparison.png', bbox_inches='tight', dpi=130)
plt.show()
print(' Sauvegardé : fig9_model_comparison.png')
# Out:
# 💾 Sauvegardé : fig9_model_comparison.png

# %% [markdown]
# ---
# ## Section 11 — TABLE 1 (rapport final)
# Ce tableau constitue la **Table 1** du rapport, qui servira de référence pour comparer les LLMs.

# %%
print('=' * 80)
print('TABLE 1 — Baseline Classifier Performance — HealthStory (FakeHealth)')
print('Features : TF-IDF unigrammes + bigrammes (max 10 000 features)')
print('Split    : 80% train / 20% test (stratifié) | Validation : 5-fold CV')
print('=' * 80)

# Header
header = f'{"Modèle":<30} {"Acc":>7} {"Prec":>7} {"Recall":>7} {"F1-mac":>7} {"F1-Fake":>8} {"F1-Real":>8} {"CV F1±σ":>13}'
print(header)
print('-' * 80)

for name, res in test_results.items():
    cv   = cv_results[name]
    cv_f1_mean = cv['test_f1_macro'].mean()
    cv_f1_std  = cv['test_f1_macro'].std()
    row = (
        f'{name:<30} '
        f'{res["accuracy"]:>7.3f} '
        f'{res["prec_macro"]:>7.3f} '
        f'{res["rec_macro"]:>7.3f} '
        f'{res["f1_macro"]:>7.3f} '
        f'{res["f1_fake"]:>8.3f} '
        f'{res["f1_real"]:>8.3f} '
        f'{cv_f1_mean:>6.3f}±{cv_f1_std:.3f}'
    )
    print(row)

print('=' * 80)
print()
print('Notes :')
print('  • F1-macro = métrique principale (déséquilibre léger 55/45)')
print('  • F1-Fake  = capacité à détecter les misinformations (critère le plus important)')
print('  • Ces valeurs sont le plancher attendu pour les LLMs zero-shot (Phase 2)')
print('  • LLMs fine-tunés (BERT/RoBERTa) devraient atteindre F1 ≈ 0.85–0.92')
# Out:
# ...
# TABLE 1 — Baseline Classifier Performance — HealthStory (FakeHealth)
# Features : TF-IDF unigrammes + bigrammes (max 10 000 features)
# Split    : 80% train / 20% test (stratifié) | Validation : 5-fold CV
# ...
# Modèle                             Acc    Prec  Recall  F1-mac  F1-Fake  F1-Real       CV F1±σ
# --------------------------------------------------------------------------------
# Logistic Regression              0.607   0.545   0.551   0.545    0.376    0.714  0.511±0.024
# Naive Bayes                      0.713   0.593   0.530   0.502    0.179    0.826  0.470±0.027
# LinearSVC                        0.626   0.563   0.571   0.564    0.400    0.729  0.509±0.026
# ...
#
# Notes :
#   • F1-macro = métrique principale (déséquilibre léger 55/45)
#   • F1-Fake  = capacité à détecter les misinformations (critère le plus important)
#   • Ces valeurs sont le plancher attendu pour les LLMs zero-shot (Phase 2)
#   • LLMs fine-tunés (BERT/RoBERTa) devraient atteindre F1 ≈ 0.85–0.92

# %%
# Export de la table en CSV pour le rapport
rows = []
for name, res in test_results.items():
    cv   = cv_results[name]
    rows.append({
        'Model'      : name,
        'Accuracy'   : round(res['accuracy'],   3),
        'Precision'  : round(res['prec_macro'],  3),
        'Recall'     : round(res['rec_macro'],   3),
        'F1_macro'   : round(res['f1_macro'],    3),
        'F1_Fake'    : round(res['f1_fake'],     3),
        'F1_Real'    : round(res['f1_real'],     3),
        'CV_F1_mean' : round(cv['test_f1_macro'].mean(), 3),
        'CV_F1_std'  : round(cv['test_f1_macro'].std(),  3),
        'Features'   : 'TF-IDF (1-2gram, max=10k)',
        'Dataset'    : 'HealthStory (FakeHealth)',
        'Split'      : '80/20 stratified',
    })

table1 = pd.DataFrame(rows)
table1.to_csv('Table1_baseline_results.csv', index=False)
print('Sauvegardé : Table1_baseline_results.csv')
print()
print(table1.to_string(index=False))
# Out:
# Sauvegardé : Table1_baseline_results.csv
#
#               Model  Accuracy  Precision  Recall  F1_macro  F1_Fake  F1_Real  CV_F1_mean  CV_F1_std                  Features                  Dataset            Split
# Logistic Regression     0.607      0.545   0.551     0.545    0.376    0.714       0.511      0.024 TF-IDF (1-2gram, max=10k) HealthStory (FakeHealth) 80/20 stratified
#         Naive Bayes     0.713      0.593   0.530     0.502    0.179    0.826       0.470      0.027 TF-IDF (1-2gram, max=10k) HealthStory (FakeHealth) 80/20 stratified
#           LinearSVC     0.626      0.563   0.571     0.564    0.400    0.729       0.509      0.026 TF-IDF (1-2gram, max=10k) HealthStory (FakeHealth) 80/20 stratified

# %% [markdown]
# ---
# ## Section 12 — Sauvegarde des modèles
# On sauvegarde les pipelines entraînés pour les comparer avec les LLMs en Phase 2.

# %%
os.makedirs('models', exist_ok=True)

for name, pipe in models.items():
    safe_name = name.lower().replace(' ', '_')
    path = f'models/{safe_name}_healthstory.pkl'
    joblib.dump(pipe, path)
    print(f' {name} → {path}')

# Sauvegarde du test set pour évaluation comparative LLM
test_export = pd.DataFrame({'text': X_test, 'label': y_test})
test_export.to_csv('healthstory_test_set.csv', index=False)
print(f' Test set → healthstory_test_set.csv ({len(test_export)} articles)')
print()
print(' Prêt pour la Phase 2 : évaluation des LLMs sur le même test set')
# Out:
#  Logistic Regression → models/logistic_regression_healthstory.pkl
#  Naive Bayes → models/naive_bayes_healthstory.pkl
#  LinearSVC → models/linearsvc_healthstory.pkl
#  Test set → healthstory_test_set.csv (321 articles)
#
#  Prêt pour la Phase 2 : évaluation des LLMs sur le même test set

# %%
# Vérification de rechargement
pipe_reload = joblib.load('models/logistic_regression_healthstory.pkl')
# Robustesse: si le modèle rechargé n'est pas encore entraîné, on l'entraîne puis on prédit
try:
    y_check = pipe_reload.predict(X_test[:10])
except Exception as e:
    if e.__class__.__name__ == 'NotFittedError':
        pipe_reload.fit(X_train, y_train)
        y_check = pipe_reload.predict(X_test[:5])
    else:
        raise
print('Vérification rechargement :')
for txt, pred, true in zip(X_test[:10], y_check, y_test[:10]):
    label_pred = 'Real' if pred == 1 else 'Fake'
    label_true = 'Real' if true == 1 else 'Fake'
    ok = '✅' if pred == true else '❌'
    print(f'  {ok} Prédit={label_pred:4s} | Vrai={label_true:4s} | {str(txt)[:80]}...')
# Out:
# Vérification rechargement :
#   ✅ Prédit=Real | Vrai=Real | Psychedelics Promise a ‘Paradigm Shift’ in Treating Mental Illness...
#   ❌ Prédit=Real | Vrai=Fake | Less Invasive Biopsies Gain Favor...
#   ❌ Prédit=Real | Vrai=Fake | Urine test for prostate cancer may be better than blood test...
#   ❌ Prédit=Real | Vrai=Fake | Study Suggests Osteoporosis Drug Might Treat Loss of Bone in Jaw...
#   ❌ Prédit=Fake | Vrai=Real | Blood injections may help chronic "tennis elbow"...
#   ❌ Prédit=Real | Vrai=Fake | Options in Treating Incontinence...
#   ✅ Prédit=Real | Vrai=Real | Dyslexia: Scanning the brain for clues...
#   ❌ Prédit=Fake | Vrai=Real | Outlook, Office, Skype, Bing, Breaking News, and Latest Videos...
#   ✅ Prédit=Real | Vrai=Real | Effectiveness of statins is called into question...
#   ❌ Prédit=Fake | Vrai=Real | Ovarian Tissue Transplant Can Help Some Women Have Kids After Cancer Treatment...

# %% [markdown]
# ---
# ## Section 13 — Résumé et prochaines étapes

# %%
print('=' * 65)
print('RÉSUMÉ NOTEBOOK 2 — Baseline FakeHealth HealthStory')
print('=' * 65)

best_model = max(test_results, key=lambda k: test_results[k]['f1_macro'])
best = test_results[best_model]
print(f'\nMeilleur modèle baseline : {best_model}')
print(f'  F1-macro  : {best["f1_macro"]:.3f}')
print(f'  F1-Fake   : {best["f1_fake"]:.3f}  (détection misinformation)')
print(f'  F1-Real   : {best["f1_real"]:.3f}')
print(f'  Accuracy  : {best["accuracy"]:.3f}')
print()
print('Fichiers générés :')
outputs = [
    'Table1_baseline_results.csv  → Table 1 du rapport',
    'healthstory_test_set.csv     → Test set pour comparaison LLM',
    'models/*.pkl                 → Modèles sauvegardés',
    'fig6–fig9_*.png              → Figures pour le rapport',
]
for o in outputs:
    print(f'  • {o}')
print()
print('Prochaines étapes (Phase 2) :')
steps = [
    'Charger healthstory_test_set.csv',
    'Évaluer GPT-4o / Claude / Mistral en zero-shot sur ce test set',
    'Évaluer GPT-4o / Claude avec few-shot (5–10 exemples)',
    'Comparer avec fine-tuning BERT/RoBERTa sur le train set',
    'Ajouter les features critères S1–S10 au baseline (expected +3–5% F1)',
    'Répliquer sur HealthRelease (cross-dataset généralisation)',
    'Répliquer sur Monant (après accès Zenodo)',
]
for i, s in enumerate(steps, 1):
    print(f'  {i}. {s}')
# Out:
# ...
# RÉSUMÉ NOTEBOOK 2 — Baseline FakeHealth HealthStory
# ...
#
# Meilleur modèle baseline : LinearSVC
#   F1-macro  : 0.564
#   F1-Fake   : 0.400  (détection misinformation)
#   F1-Real   : 0.729
#   Accuracy  : 0.626
#
# Fichiers générés :
#   • Table1_baseline_results.csv  → Table 1 du rapport
#   • healthstory_test_set.csv     → Test set pour comparaison LLM
#   • models/*.pkl                 → Modèles sauvegardés
#   • fig6–fig9_*.png              → Figures pour le rapport
#
# Prochaines étapes (Phase 2) :
#   1. Charger healthstory_test_set.csv
#   2. Évaluer GPT-4o / Claude / Mistral en zero-shot sur ce test set
#   3. Évaluer GPT-4o / Claude avec few-shot (5–10 exemples)
#   4. Comparer avec fine-tuning BERT/RoBERTa sur le train set
#   5. Ajouter les features critères S1–S10 au baseline (expected +3–5% F1)
#   6. Répliquer sur HealthRelease (cross-dataset généralisation)
#   7. Répliquer sur Monant (après accès Zenodo)
